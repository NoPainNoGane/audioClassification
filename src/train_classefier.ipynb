# %%
import os
import librosa
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.image import resize
from tensorflow.keras.models import load_model

# %%
# Step 1: Define your folder structure
data_dir = '../audio/converted'
classes = ['normal', 'deffects']

# %%
# Step 2: Load and preprocess audio data
def load_and_preprocess_data(data_dir, classes, target_shape=(128, 128)):
    data = []
    labels = []

    for i, class_name in enumerate(classes):
        class_dir = os.path.join(data_dir, class_name)
        for filename in os.listdir(class_dir):
            if filename.endswith('.wav'):
                file_path = os.path.join(class_dir, filename)
                audio_data, sample_rate = librosa.load(file_path, sr=None)
                # Perform preprocessing (e.g., convert to Mel spectrogram and resize)
                mel_spectrogram = librosa.feature.melspectrogram(y=audio_data, sr=sample_rate)
                mel_spectrogram = resize(np.expand_dims(mel_spectrogram, axis=-1), target_shape)
                data.append(mel_spectrogram)
                labels.append(i)

    return np.array(data), np.array(labels)

# %%
# Step 3: Split data into training and testing sets
data, labels = load_and_preprocess_data(data_dir, classes)
labels = to_categorical(labels, num_classes=len(classes))  # Convert labels to one-hot encoding
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# Step 4: Create a neural network model
input_shape = X_train[0].shape
input_layer = Input(shape=input_shape)
x = Conv2D(32, (3, 3), activation='relu')(input_layer)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Flatten()(x)
x = Dense(64, activation='relu')(x)
output_layer = Dense(len(classes), activation='softmax')(x)
model = Model(input_layer, output_layer)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1726494832.301091    4845 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726494832.444558    4845 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726494832.444749    4845 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726494832.446038    4845 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726494832.446179    4845 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726494832.446390    4845 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726494832.507332    4845 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726494832.507523    4845 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726494832.507672    4845 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-16 16:53:52.508187: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4414 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
# Step 5: Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Step 6: Train the model
model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1726494862.824854    6150 service.cc:146] XLA service 0x7e4fb4004700 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1726494862.824867    6150 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 2060, Compute Capability 7.5
# 2024-09-16 16:54:22.855881: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-09-16 16:54:22.995242: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# E0000 00:00:1726494863.913236    6150 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1726494864.048076    6150 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 3s 4s/step - accuracy: 0.5000 - loss: 1.0987
# I0000 00:00:1726494865.865607    6150 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.5286 - loss: 1.0360 - val_accuracy: 0.8889 - val_loss: 6.4313
# Epoch 2/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9705 - loss: 1.0136 - val_accuracy: 0.8889 - val_loss: 10.3327
# Epoch 3/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9705 - loss: 0.5398 - val_accuracy: 0.8889 - val_loss: 13.3077
# Epoch 4/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9116 - loss: 0.2263 - val_accuracy: 0.8889 - val_loss: 10.2734
# Epoch 5/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.6328e-05 - val_accuracy: 0.8889 - val_loss: 7.9994
# Epoch 6/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 2.3447e-05 - val_accuracy: 0.8889 - val_loss: 6.2831
# Epoch 7/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.1248e-05 - val_accuracy: 0.8889 - val_loss: 5.0958
# Epoch 8/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 2.1625e-05 - val_accuracy: 0.8889 - val_loss: 4.2402
# Epoch 9/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 3.8797e-05 - val_accuracy: 0.8889 - val_loss: 3.5944
# Epoch 10/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 1.0037e-04 - val_accuracy: 0.8889 - val_loss: 3.0955
# Epoch 11/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 2.3209e-04 - val_accuracy: 0.8889 - val_loss: 2.7288
# Epoch 12/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 3.4009e-04 - val_accuracy: 0.8889 - val_loss: 2.4724
# Epoch 13/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.9309e-04 - val_accuracy: 0.8889 - val_loss: 2.2900
# Epoch 14/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.0405e-04 - val_accuracy: 0.8889 - val_loss: 2.1634
# Epoch 15/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 1.4531e-04 - val_accuracy: 0.8889 - val_loss: 2.0761
# Epoch 16/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 1.0984e-04 - val_accuracy: 0.8889 - val_loss: 2.0177
# Epoch 17/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 9.1781e-05 - val_accuracy: 0.8889 - val_loss: 1.9807
# Epoch 18/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 5.5270e-05 - val_accuracy: 0.8889 - val_loss: 1.9700
# Epoch 19/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 6.2564e-05 - val_accuracy: 0.8889 - val_loss: 1.9850
# Epoch 20/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 4.9973e-05 - val_accuracy: 0.8889 - val_loss: 2.0072
# Epoch 21/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 3.8128e-05 - val_accuracy: 0.8889 - val_loss: 2.0336
# Epoch 22/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 3.1291e-05 - val_accuracy: 0.8889 - val_loss: 2.0721
# Epoch 23/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.5322e-05 - val_accuracy: 0.8889 - val_loss: 2.1146
# Epoch 24/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.0617e-05 - val_accuracy: 0.8889 - val_loss: 2.1571
# Epoch 25/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 1.7092e-05 - val_accuracy: 0.8889 - val_loss: 2.1997
# Epoch 26/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 1.4346e-05 - val_accuracy: 0.8889 - val_loss: 2.2440
# Epoch 27/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 1.1484e-05 - val_accuracy: 0.8889 - val_loss: 2.2935
# Epoch 28/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 7.2214e-06 - val_accuracy: 0.8889 - val_loss: 2.3557
# Epoch 29/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 8.4719e-06 - val_accuracy: 0.8889 - val_loss: 2.4248
# Epoch 30/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 6.8596e-06 - val_accuracy: 0.8889 - val_loss: 2.4900
# Epoch 31/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 5.7729e-06 - val_accuracy: 0.8889 - val_loss: 2.5509
# Epoch 32/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 4.9066e-06 - val_accuracy: 0.8889 - val_loss: 2.6070
# Epoch 33/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 4.2499e-06 - val_accuracy: 0.8889 - val_loss: 2.6585
# Epoch 34/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 3.7476e-06 - val_accuracy: 0.8889 - val_loss: 2.7056
# Epoch 35/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 3.3203e-06 - val_accuracy: 0.8889 - val_loss: 2.7499
# Epoch 36/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 2.2337e-06 - val_accuracy: 0.8889 - val_loss: 2.7987
# Epoch 37/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 2.7256e-06 - val_accuracy: 0.8889 - val_loss: 2.8508
# Epoch 38/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 2.2474e-06 - val_accuracy: 0.8889 - val_loss: 2.9003
# Epoch 39/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.1654e-06 - val_accuracy: 0.8889 - val_loss: 2.9482
# Epoch 40/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 1.4930e-06 - val_accuracy: 0.8889 - val_loss: 2.9972
# Epoch 41/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 1.8124e-06 - val_accuracy: 0.8889 - val_loss: 3.0474
# Epoch 42/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 1.6192e-06 - val_accuracy: 0.8889 - val_loss: 3.0921
# Epoch 43/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 1.1379e-06 - val_accuracy: 0.8889 - val_loss: 3.1378
# Epoch 44/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 1.3804e-06 - val_accuracy: 0.8889 - val_loss: 3.1843
# Epoch 45/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 1.2645e-06 - val_accuracy: 0.8889 - val_loss: 3.2252
# Epoch 46/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 8.9669e-07 - val_accuracy: 0.8889 - val_loss: 3.2658
# Epoch 47/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 1.0853e-06 - val_accuracy: 0.8889 - val_loss: 3.3068
# Epoch 48/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 1.0045e-06 - val_accuracy: 0.8889 - val_loss: 3.3427
# Epoch 49/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 9.3781e-07 - val_accuracy: 0.8889 - val_loss: 3.3742
# Epoch 50/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 8.8864e-07 - val_accuracy: 0.8889 - val_loss: 3.4019
# Epoch 51/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 8.2829e-07 - val_accuracy: 0.8889 - val_loss: 3.4267
# Epoch 52/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 8.0434e-07 - val_accuracy: 0.8889 - val_loss: 3.4491
# Epoch 53/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 7.7624e-07 - val_accuracy: 0.8889 - val_loss: 3.4693
# Epoch 54/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 7.4814e-07 - val_accuracy: 0.8889 - val_loss: 3.4874
# Epoch 55/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 7.2707e-07 - val_accuracy: 0.8889 - val_loss: 3.5039
# Epoch 56/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 7.0950e-07 - val_accuracy: 0.8889 - val_loss: 3.5189
# Epoch 57/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 6.8843e-07 - val_accuracy: 0.8889 - val_loss: 3.5328
# Epoch 58/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 6.6963e-07 - val_accuracy: 0.8889 - val_loss: 3.5459
# Epoch 59/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 6.4688e-07 - val_accuracy: 0.8889 - val_loss: 3.5586
# Epoch 60/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 6.4628e-07 - val_accuracy: 0.8889 - val_loss: 3.5710
# Epoch 61/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 6.3223e-07 - val_accuracy: 0.8889 - val_loss: 3.5827
# Epoch 62/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 6.1818e-07 - val_accuracy: 0.8889 - val_loss: 3.5938
# Epoch 63/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 4.7499e-07 - val_accuracy: 0.8889 - val_loss: 3.6084
# Epoch 64/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 5.8657e-07 - val_accuracy: 0.8889 - val_loss: 3.6262
# Epoch 65/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 5.6156e-07 - val_accuracy: 0.8889 - val_loss: 3.6425
# Epoch 66/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 5.5847e-07 - val_accuracy: 0.8889 - val_loss: 3.6577
# Epoch 67/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 5.4442e-07 - val_accuracy: 0.8889 - val_loss: 3.6716
# Epoch 68/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 5.3740e-07 - val_accuracy: 0.8889 - val_loss: 3.6845
# Epoch 69/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 5.1363e-07 - val_accuracy: 0.8889 - val_loss: 3.6967
# Epoch 70/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 5.0930e-07 - val_accuracy: 0.8889 - val_loss: 3.7084
# Epoch 71/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 4.9752e-07 - val_accuracy: 0.8889 - val_loss: 3.7194
# Epoch 72/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 4.8553e-07 - val_accuracy: 0.8889 - val_loss: 3.7303
# Epoch 73/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 4.7769e-07 - val_accuracy: 0.8889 - val_loss: 3.7408
# Epoch 74/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 4.6797e-07 - val_accuracy: 0.8889 - val_loss: 3.7511
# Epoch 75/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 4.6715e-07 - val_accuracy: 0.8889 - val_loss: 3.7612
# Epoch 76/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 4.6013e-07 - val_accuracy: 0.8889 - val_loss: 3.7709
# Epoch 77/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 4.5310e-07 - val_accuracy: 0.8889 - val_loss: 3.7801
# Epoch 78/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 4.4959e-07 - val_accuracy: 0.8889 - val_loss: 3.7891
# Epoch 79/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 4.3057e-07 - val_accuracy: 0.8889 - val_loss: 3.7980
# Epoch 80/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 4.3203e-07 - val_accuracy: 0.8889 - val_loss: 3.8069
# Epoch 81/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 4.2500e-07 - val_accuracy: 0.8889 - val_loss: 3.8156
# Epoch 82/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 4.1528e-07 - val_accuracy: 0.8889 - val_loss: 3.8243
# Epoch 83/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 4.1446e-07 - val_accuracy: 0.8889 - val_loss: 3.8331
# Epoch 84/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 4.1095e-07 - val_accuracy: 0.8889 - val_loss: 3.8417
# Epoch 85/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 4.0393e-07 - val_accuracy: 0.8889 - val_loss: 3.8501
# Epoch 86/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 4.0041e-07 - val_accuracy: 0.8889 - val_loss: 3.8582
# Epoch 87/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 4.0041e-07 - val_accuracy: 0.8889 - val_loss: 3.8663
# Epoch 88/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 3.8594e-07 - val_accuracy: 0.8889 - val_loss: 3.8746
# Epoch 89/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 3.8636e-07 - val_accuracy: 0.8889 - val_loss: 3.8831
# Epoch 90/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 3.7934e-07 - val_accuracy: 0.8889 - val_loss: 3.8914
# Epoch 91/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 3.7583e-07 - val_accuracy: 0.8889 - val_loss: 3.8996
# Epoch 92/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 3.7232e-07 - val_accuracy: 0.8889 - val_loss: 3.9076
# Epoch 93/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 3.6529e-07 - val_accuracy: 0.8889 - val_loss: 3.9154
# Epoch 94/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 3.6178e-07 - val_accuracy: 0.8889 - val_loss: 3.9231
# Epoch 95/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 3.1026e-07 - val_accuracy: 0.8889 - val_loss: 3.9329
# Epoch 96/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 3.5124e-07 - val_accuracy: 0.8889 - val_loss: 3.9446
# Epoch 97/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 3.4400e-07 - val_accuracy: 0.8889 - val_loss: 3.9557
# Epoch 98/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 2.6641e-07 - val_accuracy: 0.8889 - val_loss: 3.9697
# Epoch 99/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 3.3719e-07 - val_accuracy: 0.8889 - val_loss: 3.9861
# Epoch 100/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.6457e-07 - val_accuracy: 0.8889 - val_loss: 4.0039
# Epoch 101/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 2.8238e-07 - val_accuracy: 0.8889 - val_loss: 4.0253
# Epoch 102/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 3.0909e-07 - val_accuracy: 0.8889 - val_loss: 4.0464
# Epoch 103/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 2.9359e-07 - val_accuracy: 0.8889 - val_loss: 4.0652
# Epoch 104/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.9153e-07 - val_accuracy: 0.8889 - val_loss: 4.0821
# Epoch 105/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.8099e-07 - val_accuracy: 0.8889 - val_loss: 4.0972
# Epoch 106/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 2.7748e-07 - val_accuracy: 0.8889 - val_loss: 4.1107
# Epoch 107/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 2.7046e-07 - val_accuracy: 0.8889 - val_loss: 4.1228
# Epoch 108/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.6694e-07 - val_accuracy: 0.8889 - val_loss: 4.1340
# Epoch 109/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 2.2536e-07 - val_accuracy: 0.8889 - val_loss: 4.1462
# Epoch 110/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 2.5289e-07 - val_accuracy: 0.8889 - val_loss: 4.1595
# Epoch 111/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.4917e-07 - val_accuracy: 0.8889 - val_loss: 4.1717
# Epoch 112/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.4587e-07 - val_accuracy: 0.8889 - val_loss: 4.1831
# Epoch 113/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 2.4236e-07 - val_accuracy: 0.8889 - val_loss: 4.1935
# Epoch 114/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.4236e-07 - val_accuracy: 0.8889 - val_loss: 4.2031
# Epoch 115/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2
200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 9.8348e-08 - val_accuracy: 0.8889 - val_loss: 4.8523
# Epoch 188/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 8.5930e-08 - val_accuracy: 0.8889 - val_loss: 4.8606
# Epoch 189/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 9.8348e-08 - val_accuracy: 0.8889 - val_loss: 4.8698
# Epoch 190/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 9.8348e-08 - val_accuracy: 0.8889 - val_loss: 4.8780
# Epoch 191/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 9.4835e-08 - val_accuracy: 0.8889 - val_loss: 4.8854
# Epoch 192/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 8.7810e-08 - val_accuracy: 0.8889 - val_loss: 4.8921
# Epoch 193/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 8.7810e-08 - val_accuracy: 0.8889 - val_loss: 4.8982
# Epoch 194/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 8.7810e-08 - val_accuracy: 0.8889 - val_loss: 4.9039
# Epoch 195/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 8.6569e-08 - val_accuracy: 0.8889 - val_loss: 4.9094
# Epoch 196/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 8.6569e-08 - val_accuracy: 0.8889 - val_loss: 4.9149
# Epoch 197/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 8.7810e-08 - val_accuracy: 0.8889 - val_loss: 4.9203
# Epoch 198/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 8.7810e-08 - val_accuracy: 0.8889 - val_loss: 4.9254
# Epoch 199/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 8.7810e-08 - val_accuracy: 0.8889 - val_loss: 4.9303
# Epoch 200/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 8.4298e-08 - val_accuracy: 0.8889 - val_loss: 4.9350

# %%
test_accuracy=model.evaluate(X_test,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.8888888955116272

# %%
# Save the model
model.save('audio_classification_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Load the saved model
model = load_model('audio_classification_model.h5')

# Define the target shape for input spectrograms
target_shape = (128, 128)

# Define your class labels
classes = ['normal', 'deffects']

# Function to preprocess and classify an audio file
def test_audio(file_path, model):
    # Load and preprocess the audio file
    audio_data, sample_rate = librosa.load(file_path, sr=None)
    mel_spectrogram = librosa.feature.melspectrogram(y=audio_data, sr=sample_rate)
    mel_spectrogram = resize(np.expand_dims(mel_spectrogram, axis=-1), target_shape)
    mel_spectrogram = tf.reshape(mel_spectrogram, (1,) + target_shape + (1,))
    
    # Make predictions
    predictions = model.predict(mel_spectrogram)
    
    # Get the class probabilities
    class_probabilities = predictions[0]
    
    # Get the predicted class index
    predicted_class_index = np.argmax(class_probabilities)
    
    return class_probabilities, predicted_class_index

# Test an audio file
test_audio_file = '20240905_114622 (online-audio-converter (mp3cut.net).wav'
class_probabilities, predicted_class_index = test_audio(test_audio_file, model)

# Display results for all classes
for i, class_label in enumerate(classes):
    probability = class_probabilities[i]
    print(f'Class: {class_label}, Probability: {probability:.4f}')

# Calculate and display the predicted class and accuracy
predicted_class = classes[predicted_class_index]
accuracy = class_probabilities[predicted_class_index]
print(f'The audio is classified as: {predicted_class}')
print(f'Accuracy: {accuracy:.4f}')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# Class: normal, Probability: 0.0000
# Class: deffects, Probability: 1.0000
# The audio is classified as: deffects
# Accuracy: 1.0000
